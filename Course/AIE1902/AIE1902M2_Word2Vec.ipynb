# %% [markdown]
# ## Full Setup: `word2vec` Environment
#
# Run the following commands sequentially in your terminal:
#
# ```bash
# # Step 1: Set custom Conda environment directory (persists across sessions)
# conda config --prepend envs_dirs /directory/that/you/want/to/save/your/conda/env
#
# # Step 2: Create and activate the word2vec environment (Python 3.10)
# conda create --name word2vec python=3.10
# conda activate word2vec
#
# # Step 3: Install core dependencies
# conda install -c conda-forge numpy=1.26.4
# pip install torch==2.1.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# pip install torchtext==0.16.0
# conda install -c conda-forge gensim scikit-learn tqdm matplotlib jupyter ipykernel
#
# # Step 4: Register Jupyter kernel for VS Code (only run this if jupyter kernel cannot find your enviroment) and remember to reload window after you run the following code.
# python -m ipykernel install --user --name=word2vec --display-name "Python (word2vec)"

# %%
import os,sys
# Set the desired directory path, remember to change "xiaopengli1" to your own user name. 
os.environ['GENSIM_DATA_DIR'] = '/xiaopengli1/central_cache/gensim-data' 

import time
import torch
from torch.utils.data import DataLoader, TensorDataset
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
import torch.nn as nn
from tqdm.notebook import tqdm
import pickle
import random
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import gensim.downloader
plt.style.use('ggplot')

# %% [markdown]
# # Visualize some pretrained models.
# - See: https://radimrehurek.com/gensim/models/word2vec.html

# %%
# Pretrained models!
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
model = gensim.downloader.load('word2vec-google-news-300')

# %%
# This takes the vector for a word and gets the most similar words to this vector.
model.most_similar('banana', topn=10)
# Out:
# [('bananas', 0.7523775696754456),
#  ('pineapple', 0.6587537527084351),
#  ('mango', 0.6365211009979248),
#  ('pineapples', 0.6313878297805786),
#  ('papaya', 0.6063665747642517),
#  ('coconut', 0.6035483479499817),
#  ('potato', 0.5747568607330322),
#  ('melon', 0.5625775456428528),
#  ('cashew', 0.562165379524231),
#  ('tomato', 0.5590206384658813)]

# %%
model.most_similar('obama')
# Out:
# [('mccain', 0.7319012880325317),
#  ('hillary', 0.7284600138664246),
#  ('obamas', 0.7229632139205933),
#  ('george_bush', 0.7205674648284912),
#  ('barack_obama', 0.7045838832855225),
#  ('palin', 0.7043113708496094),
#  ('clinton', 0.6934447884559631),
#  ('clintons', 0.6816835403442383),
#  ('sarah_palin', 0.6815143823623657),
#  ('john_mccain', 0.6800707578659058)]

# %%
# x2 - x1 = y2 - y1 ... So y2 = x2 - x1 + y1 ... 
# Consider all neighbors of x2 - x1 + y1, get y2.
def analogy(model, x1, x2, y1):
    result = model.most_similar(positive=[y1, x2], negative=[x1])
    return result[0][0]

# %%
analogy(model, 'japan', 'japanese', 'australia')
# Out:
# 'canada'

# %%
analogy(model, 'obama', 'clinton', 'reagan')
# Out:
# 'kerry'

# %%
analogy(model, 'tall', 'tallest', 'long')
# Out:
# 'longest'

# %%
# Which word from the given list doesn’t go with the others?
print(model.doesnt_match("breakfast cereal dinner lunch".split()))
# Out:
# cereal

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.vocab.keys()), sample)
        else:
            words = [ word for word in model.vocab ]

    word_vectors = np.array([model[w] for w in words])

    twodim = PCA().fit_transform(word_vectors)[:,:2]

    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)

# %% [markdown]
# ### Let's project to two dimensions and see if thee are any patterns.
# We see some clusters:
# - Countries are together.
# - Drinks are together.
# - Foods.
# - Etc.

# %%
display_pca_scatterplot(
    model,
    [
        'coffee', 'tea', 'beer', 'wine', 'brandy', 'rum', 'champagne', 'water',
        'spaghetti', 'borscht', 'hamburger', 'pizza', 'falafel', 'sushi', 'meatballs',
        'dog', 'horse', 'cat', 'monkey', 'parrot', 'koala', 'lizard',
        'frog', 'toad', 'monkey', 'ape', 'kangaroo', 'wombat', 'wolf',
        'france', 'germany', 'hungary', 'france', 'australia', 'fiji', 'china',
        'homework', 'assignment', 'problem', 'exam', 'test', 'class',
        'school', 'college', 'university', 'institute'
    ]
)

# %% [markdown]
# ### Information
# - torchtext repo: https://github.com/pytorch/text/tree/main/torchtext
# - torchtext documentation: https://pytorch.org/text/stable/index.html

# %%
# Where do I want to run my job. You can do "cuda" on linux machines.
DEVICE = "cuda" if torch.cuda.is_available() else  "cpu"
# The batch size in Adam or SGD.
BATCH_SIZE = 512
# Number of epochs.
NUM_EPOCHS = 1
# Predict from 2 words the inner word for CBOW.
# I.e. I'll have a window like ["a", "b", "c"] of continuous text (each is a word).
# We'll predict each of wc = ["a", "c"] from "b" = wc for Skip-Gram.
# For CBOW, we'll use ["a", "c"] to predict "b" = wo.

# This is *NOT* used. This is "m" in lecture. It is random for each center word. See below.
WINDOW = 1

# Negative samples.
K = 4

# %%
print(DEVICE)
# Out:
# cuda

# %% [markdown]
# The text8 Wikipedia corpus. 100M characters.

# %%
# !du -h text8
# Out:
# 96M	text8

# %%
f = open('./text8', 'r')
text = f.read()
# One big string of size 100M.
print(len(text))
# Out:
# 100000000

# %%
punc = '!"#$%&()*+,-./:;<=>?@[\\]^_\'{|}~\t\n'

# Can do regular expressions here too.
for c in punc:
    text = text.replace(c, ' ')

# %%
# A very crude tokenizer you get for free: lower case and also split on spaces.
TOKENIZER = get_tokenizer("basic_english")

# %%
words = TOKENIZER(text)
f = Counter(words)

# %%
len(words)
# Out:
# 17005207

# %%
# Do a very crude filter on the text which remoes all words with low frequency
text = [word for word in words if f[word] > 5]

# %%
text[0:5]
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term']

# %%
VOCAB = build_vocab_from_iterator([text])

# %%
# word -> int hash map.
stoi = VOCAB.get_stoi()
# int -> word hash map.
itos = VOCAB.get_itos()

# %%
stoi['as']
# Out:
# 11

# %%
# Total number of words.
len(stoi)
# Out:
# 63641

# %%
f = Counter(text)
# This is the probability that we pick a word in the corpus.
z = {word: f[word] / len(text) for word in f}

# %%
threshold = 1e-5
# Probability that word is kept while subsampling.
# This is explained here and sightly differet from the paper: http://mccormickml.com/2017/01/11/word2vec-tutorial-part-2-negative-sampling/
p_keep = {word: (np.sqrt(z[word] / 0.001) + 1)*(0.0001 / z[word]) for word in f}

# %%
# This is in the integer space.
train_dataset = [word for word in text if random.random() < p_keep[word]]

# Rebuild the vocabulary.
VOCAB = build_vocab_from_iterator([train_dataset])

# %%
len(train_dataset)
# Out:
# 7846031

# %%
# word -> int mapping.
stoi = VOCAB.get_stoi()
# int -> word mapping.
itos = VOCAB.get_itos()

# %%
# The vocabulary size after we do all the filters.
len(VOCAB)
# Out:
# 63641

# %%
# The probability we draw something for negative sampling.
f = Counter(train_dataset)
p = torch.zeros(len(VOCAB))

# Downsample frequent words and upsample less frequent.
s = sum([np.power(freq, 0.75) for word, freq in f.items()])

for word in f:
    p[stoi[word]] = np.power(f[word], 0.75) / s

# %%
# Map everything to integers.
train_dataset = [stoi[word] for word in text]

# %%
# This just gets the (wc, wo) pairs that are positive - they are seen together!
def get_tokenized_dataset(dataset, verbose=False):
    x_list = []

    for i, token in enumerate(dataset):
        # Pick a RANDOM window around the center word.
        m = random.randint(1, 5)

        start = max(0,i-m)

        end = min(i+m,len(dataset)-1)

        target_tokens = dataset[start:i] + dataset[i+1:end+1]

        wc = token

        x_list.extend([
            [wc, wo] for wo in target_tokens
        ])

    return x_list

# %%
train_x_list = get_tokenized_dataset(train_dataset, verbose=False)

# %%
pickle.dump(train_x_list, open('train_x_list.pkl', 'wb'))

# %%
train_x_list = pickle.load(open('train_x_list.pkl', 'rb'))

# %%
# These are (wc, wo) pairs. All are y = +1 by design.
train_x_list[:10]
# Out:
# [[5233, 3083],
#  [5233, 11],
#  [5233, 5],
#  [5233, 172],
#  [3083, 5233],
#  [3083, 11],
#  [3083, 5],
#  [3083, 172],
#  [3083, 1],
#  [3083, 3133]]

# %%
# The number of things of BATCH_SIZE = 512.
len(train_x_list) // BATCH_SIZE
# Out:
# 195455

# %% [markdown]
# ### Set up the dataloader.

# %%
train_dl = DataLoader(
    TensorDataset(
        torch.tensor(train_x_list).to(DEVICE),
    ),
    batch_size=BATCH_SIZE,
    shuffle=True
)

# %% [markdown]
# ### Words we'll use to asses the quality of the model ...

# %%
valid_ids = torch.tensor([
    stoi['money'],
    stoi['lion'],
    stoi['africa'],
    stoi['musician'],
    stoi['dance'],
])

# %% [markdown]
# ### Get the model
# - See docs for nn.Embedding: https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html

# %%
class SkipGramNegativeSampling(nn.Module):
    def __init__(self, vocab_size, embed_dim):
        super(SkipGramNegativeSampling, self).__init__()
        self.A = nn.Embedding(vocab_size, embed_dim) # Context vectors - center word.
        self.B = nn.Embedding(vocab_size, embed_dim) # Output vectors - words around the center word.
        self.init_weights()

    def init_weights(self):
        # Is this the best way? Not sure.
        initrange = 0.5
        self.A.weight.data.uniform_(-initrange, initrange)
        self.B.weight.data.uniform_(-initrange, initrange)

    def forward(self, x):
        # N is the batch size.
        # x is (N, 2)

        # Each of these is (N, 1)
        wc, wo = x[:, 0], x[:, 1]

        # Each of these is (N, 1, D) since each context has 1 word.
        a = self.A(wc)

        # Each of these is (N, 1, D) since each target has 1 word.
        b = self.B(wo)

        # The product between each context and target vector.
        # Each of these is (N, 1, D) since each batch has 1 word.
        # The logits is now (N, 1) since we sum across the final dimension.
        logits = (a * b).sum(axis=-1)

        return logits

# %%
@torch.no_grad()
def validate_embeddings(
    model,
    valid_ids,
    itos
):
    """ Validation logic """

    # We will use context embeddings to get the most similar words
    # Other strategies include: using target embeddings, mean embeddings after avaraging context/target
    embedding_weights = model.A.weight

    normalized_embeddings = embedding_weights.cpu() / np.sqrt(
        np.sum(embedding_weights.cpu().numpy()**2, axis=1, keepdims=True)
    )

    # Get the embeddings corresponding to valid_term_ids
    valid_embeddings = normalized_embeddings[valid_ids, :]

    # Compute the similarity between valid_term_ids (S) and all the embeddings (V).
    # We do S x d (d x V) => S x D and sort by negative similarity.
    top_k = 10 # Top k items will be displayed.
    similarity = np.dot(valid_embeddings.cpu().numpy(), normalized_embeddings.cpu().numpy().T)

    # Invert similarity matrix to negative
    # Ignore the first one because that would be the same word as the probe word
    similarity_top_k = np.argsort(-similarity, axis=1)[:, 1: top_k+1]

    # Print the output.
    for i, word_id in enumerate(valid_ids):
        # j >= 1 here since we don't want to include the word itself.
        similar_word_str = ', '.join([itos[j] for j in similarity_top_k[i, :] if j >= 1])
        print(f"{itos[word_id]}: {similar_word_str}")

    print('\n')

# %% [markdown]
# ### Set up the model

# %%
LR = 10.0
EMBED_DIM = 300

# %%
model = SkipGramNegativeSampling(len(VOCAB), EMBED_DIM).to(DEVICE)
optimizer = torch.optim.SGD(model.parameters(), lr=LR)
# The learning rate is lowered every epoch by 1/10.
# Is this a good idea?
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)

# %%
model
# Out:
# SkipGramNegativeSampling(
#   (A): Embedding(63641, 300)
#   (B): Embedding(63641, 300)
# )

# %%
validate_embeddings(model, valid_ids, itos)
# Out:
# money: ctbt, impedes, expire, resistant, pantone, amnesty, outperformed, schemes, augusti, fruity
# lion: community, ll, orgasm, seminal, insulting, worldly, personae, collectivity, vecchi, greco
# africa: alveoli, friendliness, chariots, deserve, wannsee, based, injustices, kidding, dismiss, aberdeen
# musician: escu, shamanic, addresses, ayyavazhi, pavlova, genitalium, contessa, lakatos, pacify, fatally
# dance: upa, ioan, valentino, shattuck, jerseys, patrons, satisfaction, miracleman, westcott, haggis

# %% [markdown]
# ### Train the model

# %%
def train(dataloader, model, optimizer, epoch):
    model.train()
    total_acc, total_count, total_loss, total_batches = 0, 0, 0.0, 0.0
    log_interval = 1000

    for idx, x_batch in tqdm(enumerate(dataloader),
                            total=len(dataloader), 
                            desc=f"Epoch {epoch}", 
                            file=sys.stderr):

        x_batch = x_batch[0]

        batch_size = x_batch.shape[0]

        optimizer.zero_grad()

        logits = model(x_batch)

        # Get the positive samples loss. Notice we use weights here
        positive_loss = torch.nn.BCEWithLogitsLoss()(input=logits, target=torch.ones(batch_size).to(DEVICE).float())

        # For each batch, get some negative samples
        # We need a total of B * 2 * WINDOW * K samples across a batch
        # We then reshape this batch
        # These are effectively the output words
        negative_samples = torch.multinomial(p, batch_size * K, replacement=True)

        # Repeat the center word enough times so we can merge as needed
        # Repeat does not work on MPS apparently
        wc = x_batch[:, 0].to("cpu").repeat(K).sort().values
        wo = negative_samples

        # Get the negative samples
        x_batch_negative = torch.stack([wc, wo], axis=1).to(DEVICE)

        """
        Note the way we formulated the targets: they are all 0 since these are negative samples.
        We do the BCEWithLogitsLoss by hand basically here.
        Notice we sum across the negative samples, per positive word.

        This is literally the equation in the lecture notes.
        """
        negative_loss = model(x_batch_negative).neg().sigmoid().log().reshape(
            batch_size, K
        ).sum(1).mean().neg().to(DEVICE)

        loss = (positive_loss + negative_loss).mean()

        # Get the gradients via back propagation
        loss.backward()

        # Clip the gradients? Generally a good idea
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)

        # Do an optimization step. Update the parameters A and B
        optimizer.step()
        total_loss += loss.item()
        total_batches += 1

        if idx % log_interval == 0:
            progress_msg = "| epoch {:3d} | {:5d}/{:5d} batches "\
                "| loss {:8.3f} ".format(
                    epoch,
                    idx,
                    len(dataloader),
                    total_loss / total_batches
                )
            print(progress_msg)
            validate_embeddings(model, valid_ids, itos)
            total_loss, total_batches = 0.0, 0.0

# %% [markdown]
# ### Some results from the run look like below:

# %%
# Your training loop here
for epoch in range(1, NUM_EPOCHS + 1):
    epoch_start_time = time.time()
    train(train_dl, model, optimizer, epoch)
    scheduler.step()
    epoch_duration = time.time() - epoch_start_time
    print(f"Epoch {epoch} completed in {epoch_duration:.2f} seconds\n\n")
# Out:
# Epoch 1:   0%|          | 0/195456 [00:00<?, ?it/s]
# | epoch   1 |     0/195456 batches | loss    4.493
# money: ctbt, impedes, expire, resistant, pantone, amnesty, outperformed, schemes, augusti, fruity
# lion: community, ll, orgasm, seminal, insulting, worldly, personae, collectivity, vecchi, greco
# africa: alveoli, friendliness, chariots, deserve, wannsee, injustices, based, kidding, dismiss, aberdeen
# musician: escu, shamanic, addresses, ayyavazhi, pavlova, genitalium, contessa, lakatos, pacify, fatally
# dance: upa, ioan, valentino, shattuck, jerseys, patrons, satisfaction, miracleman, westcott, haggis
#
#
# | epoch   1 |  1000/195456 batches | loss    4.006
# money: ctbt, impedes, expire, pantone, schemes, amnesty, outperformed, resistant, bpm, praise
# lion: community, ll, orgasm, seminal, insulting, collectivity, greco, worldly, vecchi, personae
# africa: alveoli, friendliness, deserve, wannsee, chariots, kidding, tropospheric, injustices, based, aberdeen
# musician: escu, addresses, pavlova, shamanic, ayyavazhi, genitalium, contessa, lakatos, pacify, throwback
# dance: upa, valentino, ioan, miracleman, jerseys, shattuck, westcott, patrons, satisfaction, dispossessed
#
#
# | epoch   1 |  2000/195456 batches | loss    3.573
# money: ctbt, expire, impedes, schemes, bpm, amnesty, outperformed, augusti, pantone, ite
# lion: community, ll, orgasm, seminal, insulting, personae, worldly, collectivity, greco, vecchi
# africa: alveoli, based, friendliness, deserve, wannsee, kidding, injustices, aberdeen, tropospheric, iskcon
# musician: escu, addresses, pavlova, shamanic, contessa, ayyavazhi, genitalium, fatally, pacify, lakatos
# dance: upa, ioan, valentino, miracleman, dutch, shattuck, jerseys, westcott, haggis, sightings
#
#
# | epoch   1 |  3000/195456 batches | loss    3.258
# money: ctbt, expire, schemes, impedes, ite, bpm, ireland, hermetic, augusti, amnesty
# lion: community, ll, orgasm, seminal, insulting, greco, collectivity, personae, worldly, vecchi
# africa: based, alveoli, aberdeen, iskcon, kidding, deserve, wannsee, friendliness, see, injustices
# musician: escu, pavlova, addresses, shamanic, ayyavazhi, contessa, genitalium, pacify, lakatos, fatally
# dance: upa, valentino, ioan, miracleman, dutch, jerseys, shattuck, might, headers, contract
#
#
# | epoch   1 |  4000/195456 batches | loss    3.037
# money: area, ireland, ctbt, schemes, expire, year, augusti, bpm, hermetic, ite
# lion: community, ll, orgasm, seminal, insulting, greco, personae, vecchi, collectivity, targa
# africa: based, see, some, about, people, through, also, while, open, were
# musician: escu, addresses, pavlova, shamanic, ayyavazhi, contessa, psychiatric, lakatos, mosig, pacify
# dance: upa, dutch, miracleman, might, ioan, jerseys, contract, valentino, headers, shattuck
#
#
# | epoch   1 |  5000/195456 batches | loss    2.870
# money: area, who, year, generally, some, ireland, has, an, later, death
# lion: community, ll, seminal, orgasm, insulting, vecchi, personae, greco, targa, worldly
# africa: based, see, through, some, were, to, about, while, on, for
# musician: escu, psychiatric, lakatos, ayyavazhi, mosig, addresses, pavlova, exemption, intervene, pacify
# dance: dutch, upa, might, contract, miracleman, set, valentino, jerseys, nuclides, sightings
#
#
# | epoch   1 |  6000/195456 batches | loss    2.735
# money: area, who, year, generally, later, often, people, death, much, that
# lion: community, ll, seminal, orgasm, insulting, personae, grand, vecchi, greco, targa
# africa: based, through, some, about, see, people, these, on, in, while
# musician: escu, births, science, law, lakatos, mosig, allowed, psychiatric, addresses, years
# dance: might, dutch, set, systems, upa, population, list, addition, each, contract
#
#
# | epoch   1 |  7000/195456 batches | loss    2.633
# money: area, year, who, generally, later, her, death, first, people, some
# lion: community, ll, seminal, grand, louis, orgasm, insulting, president, personae, linear
# africa: based, about, some, from, through, people, on, while, were, also
# musician: science, law, years, births, six, isbn, known, christian, well, all
# dance: set, might, dutch, list, population, systems, each, u, state, war
#
#
# | epoch   1 |  8000/195456 batches | loss    2.546
# money: area, who, generally, year, her, death, later, an, german, people
# lion: community, ll, louis, grand, seminal, president, power, linear, orgasm, fans
# africa: based, about, from, people, through, some, while, in, see, on
# musician: science, law, births, known, years, isbn, well, four, christian, john
# dance: set, might, list, population, systems, each, dutch, war, new, state
#
#
# | epoch   1 |  9000/195456 batches | loss    2.472
# money: area, generally, who, her, death, later, year, but, german, people
# lion: community, ll, grand, louis, actor, linear, president, seminal, said, fans
# africa: based, about, from, through, people, some, most, state, was
# musician: science, law, isbn, births, seven, well, one, four, known, use
# dance: set, might, systems, population, list, war, each, dutch, u, state
#
#
# | epoch   1 | 10000/195456 batches | loss    2.406
# money: area, who, generally, year, death, later, written, her, german, through
# lion: community, ll, grand, louis, actor, president, linear, time, because, possible
# africa: based, through, about, state, people, th, some, in, early, was
# musician: isbn, law, science, nine, births, eight, well, five, seven, john
# dance: set, might, population, list, war, systems, each, north, dutch, end
#
#
# | epoch   1 | 11000/195456 batches | loss    2.352
# money: area, generally, she, death, her, who, through, written, since, later
# lion: community, ll, grand, louis, actor, president, linear, has, fans, possible
# africa: based, through, about, people, th, time, same, states, state, both
# musician: isbn, law, science, nine, five, births, john, four, seven, april
# dance: set, might, north, people, systems, age, population, each, dutch, list
#
#
# | epoch   1 | 12000/195456 batches | loss    2.309
# money: area, generally, death, she, later, who, through, since, her, known
# lion: community, ll, louis, grand, president, actor, possible, linear, york, three
# africa: based, through, people, about, some, th, british, see, both, called
# musician: isbn, four, one, law, science, six, nine, five, births, well
# dance: set, people, might, population, list, systems, u, north, end, similar
#
#
# | epoch   1 | 13000/195456 batches | loss    2.269
# money: area, generally, later, death, through, she, her, written, way, who
# lion: community, ll, louis, grand, actor, president, possible, linear, york, time
# africa: based, through, about, both, some, people, british, th, called, state
# musician: isbn, nine, three, five, science, law, one, seven, eight, d
# dance: set, north, population, list, might, systems, u, end, age, similar
#
#
# | epoch   1 | 14000/195456 batches | loss    2.231
# money: area, generally, known, through, later, death, her, she, written, way
# lion: community, ll, louis, grand, actor, president, york, possible, three, linear
# africa: based, through, and, both, people, part, nine, known, see
# musician: isbn, one, four, d, nine, eight, three, five, births, seven
# dance: set, systems, north, addition, might, population, end, because, list, similar
#
#
# | epoch   1 | 15000/195456 batches | loss    2.205
# money: area, generally, later, through, she, way, known, death, written, example
# lion: community, ll, grand, louis, actor, president, york, possible, fans, blue
# africa: based, through, s, part, th, states, state, about, british
# musician: isbn, five, seven, eight, three, four, april, births, law, nine
# dance: set, u, population, systems, end, similar, addition, north, form, s
#
#
# | epoch   1 | 16000/195456 batches | loss    2.172
# money: area, later, known, through, generally, way, death, written, view, of
# lion: community, ll, grand, louis, actor, york, three, fans, president, time
# africa: based, both, nine, th, about, people, through, part, states, early
# musician: isbn, eight, one, seven, six, april, three, zero, births, b
# dance: set, population, end, systems, u, similar, list, form, s, addition
#
#
# | epoch   1 | 17000/195456 batches | loss    2.148
# money: area, through, known, generally, later, death, or, since, time, but
# lion: community, ll, grand, actor, louis, york, fans, possible, president, early
# africa: based, both, through, th, nine, one, german, early, part, states
# musician: isbn, seven, eight, six, five, april, b, births, one, four
# dance: end, set, similar, form, s, before, population, systems, four, addition
#
#
# | epoch   1 | 18000/195456 batches | loss    2.127
# money: area, a, generally, known, death, she, people, later, but, through
# lion: community, grand, ll, louis, actor, york, possible, fans, president, time
# africa: both, based, th, about, and, one, nine, states, early, north
# musician: isbn, seven, four, one, april, d, nine, births, six, b
# dance: end, set, similar, population, about, people, form, addition, international, systems
#
#
# | epoch   1 | 19000/195456 batches | loss    2.105
# money: area, generally, known, death, time, but, through, she, has, did
# dance: zero, end, see, similar, at, these, based, of, considered, new
#
#
# | epoch   1 | 29000/195456 batches | loss    1.967
# money: however, generally, of, same, found, she, though, did, as, often
# lion: community, louis, m, ll, five, grand, and, early, fans, actor
# africa: south, europe, west, east, states, european, north, united, part, three
# musician: eight, seven, b, six, one, isbn, five, three, nine, april
# dance: and, see, main, its, end, similar, based, addition, from, like
#
#
# | epoch   1 | 30000/195456 batches | loss    1.957
# money: generally, however, she, same, did, so, found, though, not, they
# lion: five, louis, ll, community, m, early, at, three, eight, fans
# africa: europe, south, east, west, states, european, united, part, north, america
# musician: eight, one, nine, seven, six, b, five, isbn, three, april
# dance: from, end, see, of, like, second, based, these, addition, music
#
#
# | epoch   1 | 31000/195456 batches | loss    1.947
# money: however, she, which, generally, so, did, they, same, found, although
# lion: ll, louis, community, at, three, seven, five, s, early
# africa: south, europe, east, european, west, states, north, part, united, america
# musician: b, eight, nine, six, five, three, seven, isbn, one, zero
# dance: end, based, music, s, form, and, from, these, at, addition
#
#
# | epoch   1 | 32000/195456 batches | loss    1.939
# money: she, however, so, generally, did, they, possible, and, though, found
# lion: ll, at, louis, early, community, i, fans, seven, where, july
# africa: europe, south, east, north, european, west, part, united, states, and
# musician: nine, eight, five, seven, six, b, four, isbn, april, three
# dance: music, end, addition, form, considered, based, similar, such, each
#
#
# | epoch   1 | 33000/195456 batches | loss    1.932
# money: so, she, however, generally, work, which, found, same, possible, they
# lion: ll, louis, i, early, three, seven, community, first, york, fans
# africa: south, europe, east, north, european, west, united, part, america, states
# musician: eight, nine, five, b, seven, four, one, isbn, six, three
# dance: music, similar, in, considered, end, based, such, addition, known, like
#
#
# | epoch   1 | 34000/195456 batches | loss    1.926
# money: she, however, did, so, generally, work, same, though, possible, found
# lion: ll, louis, early, two, seven, community, york, three, being, five
# africa: europe, south, east, north, west, united, european, and, part, states
# musician: eight, nine, seven, six, b, isbn, five, one, three, four
# dance: in, music, similar, considered, such, development, addition, end, each
#
#
# | epoch   1 | 35000/195456 batches | loss    1.920
# money: so, did, time, however, she, generally, work, found, though, possible
# lion: five, ll, louis, seven, three, community, at, one, york, then
# africa: europe, south, east, north, west, united, european, part, america, th
# musician: one, six, b, nine, seven, five, eight, isbn, four, d
# dance: music, and, new, in, history, based, main, development, such, end
#
#
# | epoch   1 | 36000/195456 batches | loss    1.911
# money: so, generally, however, time, she, work, though, did, possible, found
# lion: seven, five, nine, ll, s, louis, zero, being, community, four
# africa: east, south, europe, north, west, european, united, america, part, central
# musician: nine, eight, b, four, six, five, seven, isbn, one, d
# dance: music, new, original, based, main, development, addition, like, history, form
#
#
# | epoch   1 | 37000/195456 batches | loss    1.904
# money: so, however, she, generally, though, possible, did, this, work, time
# lion: seven, five, ll, louis, community, three, four, eight, york, being
# africa: east, south, europe, west, european, north, america, united, part, states
# musician: b, nine, four, eight, six, one, seven, isbn, five, april
# dance: music, new, based, development, addition, main, original, similar, end, called
#
#
# | epoch   1 | 38000/195456 batches | loss    1.897
# money: so, though, she, possible, work, found, did, time, place, that
# lion: s, five, ll, seven, community, louis, being, four, at, july
# africa: east, south, europe, west, european, north, america, part, united, central
# musician: b, one, six, nine, four, eight, isbn, five, april, seven
# dance: music, based, new, development, in, end, original, main, s
#
#
# | epoch   1 | 39000/195456 batches | loss    1.888
# money: so, though, work, possible, found, however, she, generally, of, become
# lion: seven, ll, three, louis, community, five, m, being, july, then
# africa: south, east, europe, west, north, european, america, part, western, united
# musician: six, seven, nine, eight, b, isbn, four, three, five, april
# dance: music, new, development, based, main, developed, end, modern, addition, similar
#
#
# | epoch   1 | 40000/195456 batches | loss    1.886
# money: so, possible, found, become, though, time, work, even, however, did
# lion: three, seven, ll, community, louis, four, m, six, being, july
# africa: south, east, europe, west, north, european, america, part, western, united
# musician: seven, b, nine, one, four, six, isbn, eight, april, three
# dance: music, based, development, new, in, both, for, main, means
#
#
# | epoch   1 | 41000/195456 batches | loss    1.879
# money: so, possible, work, though, found, but, become, she, however, did
# lion: seven, ll, however, m, louis, july, became, where, l, actor
# africa: south, east, west, europe, north, america, european, western, part, central
# musician: b, eight, seven, one, four, isbn, nine, five, actor, april
# dance: music, new, based, development, main, developed, end, while, addition, in
#
#
# | epoch   1 | 42000/195456 batches | loss    1.874
# money: so, time, possible, though, but, however, work, found, become, being
# lion: ll, five, m, being, louis, star, s, l, community, july
# africa: east, south, west, europe, north, america, european, western, and, part
# musician: eight, b, seven, isbn, nine, actor, one, four, april, five
# dance: music, based, in, development, new, addition, developed, written, end, main
#
#
# | epoch   1 | 43000/195456 batches | loss    1.870
# money: possible, but, so, found, even, work, though, little, time, although
# lion: ll, five, louis, three, actor, community, star, co, seven, being
# africa: east, south, west, europe, america, western, north, european, central, part
# musician: eight, b, isbn, one, actor, nine, d, four, seven, two
# dance: music, based, addition, major, one, development, written, considered, developed, history
#
#
# | epoch   1 | 44000/195456 batches | loss    1.863
# money: possible, so, however, work, found, though, become, but, although, even
# lion: ll, one, louis, two, six, actor, and, july, l, star
# africa: east, south, europe, west, america, north, western, european, central, china
# musician: eight, one, isbn, actor, four, b, seven, six, born, d
# dance: music, based, major, of, addition, means, development, while, history
#
#
# | epoch   1 | 45000/195456 batches | loss    1.860
# money: possible, though, found, so, although, work, however, because, become, even
# lion: nine, ll, six, louis, five, actor, july, and, being, l
# africa: east, south, europe, west, america, western, north, european, central, region
# musician: b, six, actor, eight, isbn, d, five, nine, one, seven
# dance: music, based, major, addition, development, new, means, for, written, history
#
#
# | epoch   1 | 46000/195456 batches | loss    1.850
# money: so, possible, found, though, even, work, although, not, because, become
# lion: six, five, ll, actor, louis, seven, july, four, l, s
# africa: east, south, europe, west, america, western, central, countries, european, part
# musician: b, eight, six, actor, nine, isbn, born, d, five, seven
# dance: music, based, development, history, major, new, written, means, addition, from
#
#
# | epoch   1 | 47000/195456 batches | loss    1.850
# money: possible, however, work, though, become, found, even, so, although, not
# lion: s, ll, nine, one, louis, actor, at, story, july, became
# africa: south, east, europe, america, west, western, countries, central, part, european
# musician: nine, b, eight, actor, five, six, isbn, born, d, four
# dance: music, based, history, while, development, new, written, major, developed, means
#
#
# | epoch   1 | 48000/195456 batches | loss    1.846
# money: possible, even, though, so, not, found, work, little, although, still
# lion: s, ll, louis, actor, story, became, one, six, five, at
# africa: south, europe, east, america, west, western, european, part, central, north
# musician: six, nine, one, b, four, five, actor, seven, isbn, eight
# dance: music, based, addition, history, new, written, modern, development, program, developed
#
#
# | epoch   1 | 49000/195456 batches | loss    1.841
# money: possible, work, however, so, even, though, little, still, although, not
# lion: s, ll, louis, actor, at, l, while, one, story, became
# africa: south, europe, east, west, america, north, western, central, european, region
# musician: b, six, nine, seven, actor, born, eight, four, isbn, singer
# dance: music, based, addition, history, developed, means, written, literature, development, culture
#
#
# | epoch   1 | 50000/195456 batches | loss    1.836
# money: possible, though, still, because, its, work, even, however, found, to
# lion: six, s, ll, l, louis, story, is, actor, july
# africa: south, europe, east, west, america, western, european, north, central, countries
# musician: b, nine, six, seven, born, actor, four, singer, isbn, eight
# dance: music, based, addition, country, means, culture, developed, written, within
#
#
# | epoch   1 | 51000/195456 batches | loss    1.830
# money: possible, though, however, its, work, same, so, still, even, an
# lion: six, ll, louis, l, actor, star, three, four, one, eight
# africa: south, europe, east, america, west, north, european, western, central, countries
# musician: six, actor, b, singer, born, nine, isbn, seven, one, writer
# dance: music, based, country, written, culture, addition, traditional, means, developed, new
#
#
# | epoch   1 | 52000/195456 batches | loss    1.830
# money: possible, work, though, even, its, so, because, same, however, little
# lion: ll, is, actor, louis, four, l, s, july, three, it
# africa: south, europe, west, america, east, north, western, european, region, central
# musician: four, actor, nine, eight, b, singer, born, isbn, six, seven
# dance: music, based, written, traditional, country, popular, new, culture, considered, addition
#
#
# | epoch   1 | 53000/195456 batches | loss    1.829
# money: possible, work, its, though, so, even, because, little, although, same
# lion: s, ll, louis, it, actor, six, nine, story, l, uk
# africa: south, west, europe, east, america, north, european, western, region, central
# musician: nine, six, actor, singer, born, eight, b, four, seven, d
# dance: music, based, new, country, written, culture, old, traditional, sound
#
#
# | epoch   1 | 54000/195456 batches | loss    1.822
# money: work, so, possible, but, though, because, their, even, little, only
# lion: five, six, star, ll, it, louis, l, uk, seven, three
# africa: south, europe, america, west, east, north, western, european, region, countries
# musician: b, actor, born, singer, six, eight, three, seven, d, four
# dance: music, country, based, old, culture, modern, began, written, history, sound
#
#
# | epoch   1 | 55000/195456 batches | loss    1.821
# money: so, because, possible, work, though, little, even, she, place, but
# lion: star, five, six, l, ll, seven, louis, son, story, uk
# africa: south, europe, west, east, america, north, western, european, region, china
# musician: actor, singer, b, born, six, one, nine, writer, isbn, eight
# dance: music, culture, began, country, based, written, for, old, sound, style
#
#
# | epoch   1 | 56000/195456 batches | loss    1.817
# money: because, so, but, work, possible, though, only, he, same, little
# lion: ll, star, six, louis, s, story, l, show, uk, son
# africa: south, europe, east, west, america, north, western, india, african, european
# musician: nine, b, actor, singer, born, three, isbn, eight, writer, d
# dance: music, country, culture, began, style, old, sound, written, means, use
#
#
# | epoch   1 | 57000/195456 batches | loss    1.808
# money: so, because, though, possible, work, but, little, only, time, same
# lion: s, ll, star, louis, one, l, uk, it, what, fact
# africa: south, europe, west, east, america, north, india, western, region, african
# musician: b, singer, actor, nine, one, four, born, d, isbn, three
# dance: music, country, for, culture, new, began, sound, style, means, modern
#
#
# | epoch   1 | 58000/195456 batches | loss    1.809
# money: because, so, possible, but, though, work, even, same, should, little
# lion: star, four, louis, six, ll, uk, at, it, s, l
# africa: south, europe, america, west, east, north, india, african, western, country
# musician: b, nine, singer, actor, eight, d, born, seven, one, four
# dance: music, country, style, new, based, sound, old, culture, modern, means
#
#
# | epoch   1 | 59000/195456 batches | loss    1.807
# money: because, but, possible, so, though, work, same, to, thus, should
# lion: four, star, six, louis, at, possible, actor, ll, uk, house
# africa: south, europe, west, america, east, north, india, african, region, western
# musician: actor, singer, b, d, born, four, seven, six, eight, writer
# dance: music, new, culture, style, country, sound, based, modern, considered, means
#
#
# | epoch   1 | 60000/195456 batches | loss    1.804
# money: because, possible, but, though, so, work, thus, same, given, little
# lion: four, star, five, louis, at, six, actor, house, ll, leadership
# africa: south, europe, east, west, america, north, india, region, northern, country
# musician: actor, singer, b, one, born, d, eight, four, nine, writer
# dance: music, country, culture, style, new, considered, sound, popular, historical, old
#
#
# | epoch   1 | 61000/195456 batches | loss    1.798
# money: but, because, work, possible, though, so, thus, given, little, need
# lion: five, star, s, house, uk, louis, then, four, leadership, at
# africa: south, europe, america, east, west, north, region, india, northern, across
# musician: singer, actor, b, d, born, writer, four, nine, eight, isbn
# dance: music, culture, style, country, new, popular, considered, literature, based, historical
#
#
# | epoch   1 | 62000/195456 batches | loss    1.800
# money: because, possible, but, work, so, though, still, little, given, thus
# lion: star, s, house, uk, five, louis, actor, leadership, eight
# africa: south, europe, america, east, north, west, northern, india, region, across
# musician: singer, b, actor, born, seven, one, eight, writer, d, nine
# dance: music, culture, new, style, country, modern, popular, considered, rock, literature
#
#
# | epoch   1 | 63000/195456 batches | loss    1.796
# money: possible, because, so, but, work, little, given, having, thus, need
# lion: star, house, actor, uk, louis, then, leadership, possible, story, book
# africa: south, europe, america, east, northern, north, west, india, western, asia
# musician: singer, actor, b, seven, born, one, four, writer, nine, d
# dance: music, culture, style, country, new, modern, popular, considered, rock, based
#
#
# | epoch   1 | 64000/195456 batches | loss    1.793
# money: so, possible, work, because, time, little, given, power, same, need
# lion: star, actor, louis, then, seven, leadership, house, s, uk, story
# africa: south, europe, america, east, north, northern, western, west, india, asia
# musician: singer, actor, b, writer, born, nine, d, four, three, author
# dance: music, new, culture, style, country, popular, considered, rock, based, literature
#
#
# | epoch   1 | 65000/195456 batches | loss    1.790
# money: so, possible, but, because, work, still, time, need, same, given
# lion: s, star, actor, of, leadership, louis, uk, eight, seven
# africa: south, europe, america, east, northern, india, north, asia, western, region
# musician: singer, actor, writer, b, born, eight, d, one, author, nine
# dance: music, country, culture, style, popular, new, literature, considered, written, based
#
#
# | epoch   1 | 66000/195456 batches | loss    1.787
# money: possible, still, so, need, because, but, time, work, given, power
