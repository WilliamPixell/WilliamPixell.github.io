# %% [markdown]
# # Environment Setup
#
# ## 1. Configure Conda Environment Directory
#
# If you want to save conda environments to a custom location:
# ```bash
# conda config --prepend envs_dirs /directory/that/you/want/to/save/your/conda/env
# ```
#
# ## 2. Create and Activate Environment
#
# Clone from an existing `RNNwikitext2` environment to create `GPT1`:
# ```bash
# conda create --name GPT1 --clone RNNwikitext2
# conda activate GPT1
# ```
#
# ## 3. Install Dependencies
# ```bash
# pip install gdown
# pip install tokenizers
# ```
#
# ## 4. Register Jupyter Kernel
# ```bash
# python -m ipykernel install --user --name=GPT1 --display-name "GPT1"
# ```

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# Hyperparameters.
# I suggest you start with very small values, unless you have a strong PC or are running on the cluster
batch_size = 64 # How many independent sequences will we process in parallel?
# block_size = 128 # What is the maximum context length for predictions?
block_size = 256
max_iters = 5000 # Max iterations we run the optimization
# max_iters = 10000

# How often we evaluate across the optimization; every 500 iterations
eval_interval = 500
# eval_interval = 200
learning_rate = 3e-4
# learning_rate = 1e-3

"""
Use 'mps' if on a mac as below:

device = 'mps' if torch.backends.mps.is_available() else 'cpu'
"""
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# How many batches we use each time we evaluate
eval_iters = 500
d_model = 192
# d_model = 384
# n_head = 6 # This implied that each head has a dimension for the key, query, and values of d_model / 6.
# n_layer = 6 # This implies we have 6 turns to mix the embeddigs; this is "Nx" in the paper
n_head = 6
n_layer = 4
dropout = 0.2
# dropout = 0.2
# ------------

FILL_IN = "FILL_IN"

torch.manual_seed(1337)

# %%
# !gdown 'https://drive.google.com/uc?export=download&id=1RlmRmXiWVKpZq98ftdtOIdM2lsA1uw3j'
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1RlmRmXiWVKpZq98ftdtOIdM2lsA1uw3j
# To: /xiaopengli1/Courses/AIE1902/hemingway.txt
# 100%|████████████████████████████████████████| 133k/133k [00:00<00:00, 3.26MB/s]

# %% [markdown]
# As usual, we read the text file and then get two dictionaries from char to idx and in reverse. char embeddings is what we will use here.

# %%
# # with open('hemingway.txt', 'r', encoding='utf-8') as f:
# #     text = f.read()

# with open('hemingway_combined.txt', 'r', encoding='utf-8') as f:
#     text = f.read()

# # Here are all the unique characters that occur in this text
# chars = sorted(list(set(text)))
# vocab_size = len(chars)
# # Create a mapping from characters to integers
# stoi = { ch:i for i,ch in enumerate(chars) }
# itos = { i:ch for i,ch in enumerate(chars) }
# encode = lambda s: [stoi[c] for c in s] # Encoder: take a string, output a list of integers
# decode = lambda l: ''.join([itos[i] for i in l]) # Decoder: take a list of integers, output a string

# # Train and Test splits
# data = torch.tensor(encode(text), dtype=torch.long)
# n = int(0.9*len(data)) # First 90% will be train, rest val
# train_data = data[:n]
# val_data = data[n:]

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import ByteLevel
from tokenizers.decoders import ByteLevel as ByteLevelDecoder  # Add this!


# with open('hemingway.txt', 'r', encoding='utf-8') as f:
#     text = f.read()

with open('hemingway_combined.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f"Text length: {len(text):,} characters")

# ============================================================
# Train BPE using HuggingFace tokenizers
# ============================================================

# Initialize a BPE tokenizer

tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer = ByteLevel(add_prefix_space=False)  # Preserves \n
tokenizer.decoder = ByteLevelDecoder()  # Add this line!


trainer = BpeTrainer(
    vocab_size=5000,
    special_tokens=["[UNK]", "[PAD]", "[BOS]", "[EOS]"]
)
tokenizer.train(files=['hemingway_combined.txt'], trainer=trainer)


# Save for later use (optional)
tokenizer.save("hemingway_bpe.json")

vocab_size = tokenizer.get_vocab_size()
print(f"BPE Vocabulary size: {vocab_size}")

# Define encode/decode functions (same interface as before)
encode = lambda s: tokenizer.encode(s).ids
decode = lambda l: tokenizer.decode(l)

# Show example
example = "The old man was thin and gaunt with deep wrinkles."
tokens = tokenizer.encode(example)
print(f"\nExample: '{example}'")
print(f"Token IDs: {tokens.ids}")
print(f"Tokens: {tokens.tokens}")
print(f"Decoded: '{decode(tokens.ids)}'")

# Train and Test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

print(f"\nTotal tokens: {len(data):,}")
print(f"Compression: {len(text)/len(data):.1f} chars/token")
# Out:
# Text length: 965,607 characters
#
#
#
# BPE Vocabulary size: 5000
#
# Example: 'The old man was thin and gaunt with deep wrinkles.'
# Token IDs: [164, 369, 290, 156, 1936, 122, 143, 56, 2679, 205, 1455, 4665, 546, 14]
# Tokens: ['The', 'Ġold', 'Ġman', 'Ġwas', 'Ġthin', 'Ġand', 'Ġg', 'a', 'unt', 'Ġwith', 'Ġdeep', 'Ġwrink', 'les', '.']
# Decoded: 'The old man was thin and gaunt with deep wrinkles.'
#
# Total tokens: 276,527
# Compression: 3.5 chars/token

# %%
# Data loading
def get_batch(split):
    # Generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    # Randomly select batch_size rows from data's row indices
    ix = torch.randint(data.shape[0]-block_size, (batch_size,))
    # Select batch_size chuncks of text each of size block_size; stack them
    xb = torch.stack([data[i:i+block_size] for i in ix])
    # Do the same for y, but make sure that this is shifted over by 1
    yb = torch.stack([data[i+1:i+block_size+1] for i in ix])
    # I.e. if you select xb (1, 2, 3, 4), yb should be (2, 3, 4, 5)
    xb, yb = xb.to(device), yb.to(device)
    # Each of xb, yb should be (batch_size, block_size)
    return xb, yb

# %%
@torch.no_grad()
def estimate_loss(model):
    out = {}
    # Put the model in eval mode here
    model.eval()
    for split in ['train', 'val']:
        # Initilize an array of tensor of zeros of size eval_iters
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            # Get a batch of data
            xb, yb = get_batch(split)
            # Get the mean and loss
            logits, loss = model(xb, yb)
            # Get the loss for this batch
            losses[k] = loss.item()
        # Insert the mean estimate for the loss, based on the slit you are in
        out[split] = losses.mean()
    # Put the model in train mode here
    model.train()
    return out

# %%
class Head(nn.Module):
    """
    This class represents one head of self-attention
    Note that since this is a Decoder, this is masked-self-attention
    There is no Encoder, so there is no cross-self-attention
    """

    def __init__(self, d_head):
        super().__init__()
        self.d_head = d_head
        # Map each key, query, or value in to a d_head dimensional model.
        # Each should be matrices from d_model to d_head
        self.W_K = nn.Linear(d_model, d_head, bias=False)
        self.W_Q = nn.Linear(d_model, d_head, bias=False)
        self.W_V = nn.Linear(d_model, d_head, bias=False)
        self.d_head = d_head
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # (B, T, d_model)
        # B = batch_size, T = block_size in the below
        B,T,d = x.shape
        # Get the key and query representations from the embedding x
        # (B,T,d_head)
        k = self.W_K(x)
        # (B,T,d_head)
        q = self.W_Q(x)
        # (B,T,d_head)
        v = self.W_V(x)

        # Compute attention scores, and get the new representations for this head

        # (B T, d_head) @ (B, d_head, T) = (B, T, T)
        # Multiply q by k and divide by the appropriate constant
        scores = q @ k.transpose(1,2) / torch.sqrt(torch.tensor(self.d_head))

        # (B, T, T)
        # Apply a mask to scores, making all scores above the diagonal -inf
        scores = scores.masked_fill(self.tril[:T,:T]==0, -float('inf'))

        # (B, T, T)
        # Apply softmax to the final dimension of scores
        a =  F.softmax(scores, dim=2)

        # Apply dropout
        a = self.dropout(a)
        # Perform the weighted aggregation of the values
        # Using a and v, get the new representations
        # (B, T, T) @ (B, T, d_head) -> (B, T, d_head)
        out = a @ v
        # For each token, return the weighted sum of the values
        return out

class MultiHeadAttention(nn.Module):
    """
    Multiple heads of self-attention in parallel
    You can have just sequential code below
    """

    def __init__(self, num_heads, d_head):
        super().__init__()
        self.heads = nn.ModuleList([Head(d_head) for _ in range(num_heads)])
        # This is to project back to the dimension of d_model. In this case, it is just a learned linear map
        self.W_O = nn.Linear(num_heads*d_head, d_model)
        # self.W_O = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Concatenate the different representations per head along the last dimension
        out = torch.cat([head(x) for head in self.heads], dim=-1)
        # Project the concatenation and apply dropout; this is the W_O in "Attention is all you need"
        out = self.dropout(self.W_O(out))
        return out

# %%
class FeedFoward(nn.Module):
    """
    A simple linear layer followed by a non-linearity; this is applied at the token level
    """

    def __init__(self, d_model):
        super().__init__()
        d_ff = 4 * d_model
        # Map each token via a linear map to d_ff, apply ReLU, map back to d_model, and then apply dropout
        # This can be done with nn.Sequential
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.ff(x)

# %%
class DecoderBlock(nn.Module):
    """
    Transformer decoder block: communication followed by computation
    These are stacked on top of each other one after another
    """

    def __init__(self, d_model, n_head):
        super().__init__()
        # Each head gets a smaller dimensional representation of the data
        # Assume each head gets a representation of dimension d_head and d_model is divisible by n_head
        d_head = d_model // n_head
        self.sa = MultiHeadAttention(n_head, d_head)
        self.ff = FeedFoward(d_model)
        self.ln1 = nn.LayerNorm(d_model)
        self.ln2 = nn.LayerNorm(d_model)

    def forward(self, x):
        """
        This is different from the originl transformer paper
        In the "Attention is all you need" paper, we had
        x = self.ln1(x + self.sa(x))
        x = self.ln2(x + self.ffwd(x))
        See Figure 1 here, and mimic that: https://arxiv.org/pdf/2002.04745.pdf

        Here, you can also do:
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        """
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

# %%
class GPT(nn.Module):
    def __init__(self):
        super().__init__()
        # Each token directly reads off the logits for the next token from a lookup table
        # Token embeddings are from vocab_size to d_model
        self.token_embedding_table = nn.Embedding(vocab_size, d_model)
        # Position embeddings are from block_size (T) to d_model
        self.position_embedding_table = nn.Embedding(block_size, d_model)
        # This should be n_sequential applications of a DecoderBlock
        # This is the "Nx" piece in the paper
        self.blocks = nn.Sequential(*[DecoderBlock(d_model,n_head) for i in range(n_layer)])
         # Final layer norm
        self.ln = nn.LayerNorm(d_model)
        self.ff = nn.Linear(d_model, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        # (B,T,d_model)
        tok_emb = self.token_embedding_table(idx)
        # (T,d_model)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        # Add positional encodings to encodings
        # (B,T,d_model)
        x = tok_emb + pos_emb

        # Mix up the token representations over and over via the blocks
        # (B,T,d_model)
        x = self.blocks(x)

        # Apply layer norm
        # (B,T,d_model)
        x = self.ln(x)

        # Apply the final linear map, to get to dimension vocab_size
        # (B,T,vocab_size)
        logits = self.ff(x)

        if targets is None:
            loss = None
        else:
            B, T, V = logits.shape
            logits = logits.view(B*T, V)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        """
        idx is (B, T) array of indices in the current context
        This will generate B total paths in parrallel
        We will just geenrate 1 batch below
        """
        self.eval()
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            # The model only has kowledge of the context of maximum size block_size
            # Get the newest (B, T) data; T = block_size
            idx_cond = idx[:, -block_size:]

            # Get the predictions
            # (B, T, vocab_size)
            logits, loss = self(idx_cond)

            # Focus only on the last time step, get the logits
            # (B, vocab_size)
            logits = logits[:, -1, :]

            # Apply softmax to get probabilities
            # (B, vocab_size)
            probs = F.softmax(logits, dim=1)

            # Sample from the distribution proporttional to probs
            # (B, 1)
            idx_next = torch.multinomial(probs, 1)

            # Append sampled index to the running sequence
            # (B, T+1)
            idx = torch.cat([idx, idx_next], dim=1)
        self.train()
        return idx

# %%
class EarlyStopping:
    def __init__(self, tolerance=5, min_delta=0):

        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) / train_loss > self.min_delta:
            self.counter += 1
            if self.counter >= self.tolerance:
                self.early_stop = True

# %%
model = GPT().to(device)
# Print the number of parameters in the model
# print("The number of parameters: ", sum(w.numel() for w in model.parameters()))
print(sum(p.numel() for p in model.parameters()) / 1e6, 'M parameters')

# Create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.9)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, max_iters, eta_min=1e-5)

# early_stopping = EarlyStopping(tolerance=1, min_delta=0.2)
early_stopping = EarlyStopping(tolerance=2, min_delta=0.2)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        if iter:
          scheduler.step()
        losses = estimate_loss(model)
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        early_stopping(losses['train'], losses['val'])
        if early_stopping.early_stop:
          print("We stop at epoch {}".format(iter))
          break


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# 3.751688 M parameters
# step 0: train loss 8.7103, val loss 8.7181
# step 500: train loss 4.3219, val loss 4.4024
# step 1000: train loss 3.8110, val loss 4.1359
# step 1500: train loss 3.4953, val loss 4.0202
# step 2000: train loss 3.2829, val loss 3.9769
# step 2500: train loss 3.1100, val loss 3.9766
# We stop at epoch 2500

# %%
# Start the model with a new line, generate up to 10000 tokens
# This is technically doing generations in batches, but here we have a batch size of 1 and 1 element to start in the batch
# If you have a model that's very lazrge, d_model = 384, n_head = 6, n_layer = 6, you'll get fairly decent results
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=1000)[0].tolist()))
open('fake_hemingway.txt', 'w').write(decode(model.generate(context, max_new_tokens=1000)[0].tolist()))
# Out:
# . Awe liked the signs, The road dropped off on the
# light and watched side. I found a thin light.
#
# The road was awfullyened in the sunapnel as we leaned on our bags recovered. I woke,
# left in the house and across the forest of wet beyond the early morning,
# faceack
# ey’s narrow street. The maid was through shoulders was white paper. On the trees were building as they singing and it were all
# feers. All the railway Men were moder two rounded and muddy main
# two sheltered toast oil everyweights and shell had a stone water and dirty went away. There was smooth
# was a full. There were very
# s store on their facescut to bear from fresh and many military, and
# alking as on theThe wind had been floated. He had been dreamed of
# was lunch. You repeasants. They had a yellow rate jockey,
# Den consider Kelled at the time he put the fields. The café
# dancing),ed, so that we had coffee and they worked good into the one hundred lire together.
#
# By a dozen day and we got down to all dancing-station wine and got into the river. I went out of the
# way down on a leak. About a spead, so I
# then held me a ten felt very slowly for the concierge and turned her to lunch and
# the table and then as
# lood had been old girl sat that shone. There was allowed up and I met it seemed to be
# joature. When I told them over and give me up from condards I did notbrandy. I rubbed the Ospedale Maggiore
# any—that came back for the mountains so that had to
# stragated on in Milanome, and another potblacks
# with my arm around the sched. He had been forwardket or three ambulances. He
# him and have out of them to see one else
# shoulder. He's would speak. It was something seemed to make one. Three of
# porratieris what’s of the Hotel Montoyaghty they took off my complicated the neck. He was under this
# s early way from under less and the rain.
#  We went on a bottle. I climbed up on a trout-stairs and gold-bottle. The
# drives under the pillow. Piani went on one of my feet empty gray.
#
# “Thank you I got that?” he asked.
#
# “Good boy, the two fellow.”
#
# He pulled to kiss him away and wiped on the woman with a wild
# from the seat and clutters.
#
# “What is the States?”
#
# “Yes,” I said. “He shook perceptible.”
#
# He went around.
#
# “I are,” I said, “I’m going to
# m two hundred-night!”
#
# “He got a little village,” Bill said. We went back to the hotel on the embankment
# the road brought up across seven oartearss beside the rolling and
# and more. The other part
# people I went we did not see the road between Bruttering
# window. I was around the bags for the ripped across the street across
# the cloth it.
#
# “What are you like this thing there?” Bill asked.
#
# “They used to talk to the brush more I buy a thousand lire.”
#
# “Take a drink at ten francs. This day time of the road. It must have been since it would be a bridge. We
# been many more one who wore a car with the drivers came by looking at a
# below for the top of time. These were rigged out, spinner from
# and they had shot spread up. It was a _answgage stopped. The café in the house was
# close to be a fine beach. We passed through the village-shop in the sprinkled bank of vie time they were
# untilway while
# ans’llums boys shouted. Lil track at the army. Alockntto give you knew the
# low business. In the time every one was locked and the embankment and the
# boiling in the road when they had the stretchers. There were many tricks and snow and troops
# land-cars got up and shialled. In the stands was a good-trees around his ditch. There
# splashed road to the grass and there were furnit. The fields were many men who wanted to them and
# the breeze when the dugout. We passed the crowd
# that there are soldiers came out on and shoulders going on top. It had
# Through in the British Emilacace and others be safe looked through the line of the
# dining
# 3960

# %%
torch.save(model.state_dict(), 'gpt.pt')

# %%
# Start with actual text
prompt = "The old man"
context = torch.tensor([encode(prompt)], dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=200)[0].tolist()))
# Out:
# The old man saw his head as he rose the shoulder. Then he saw the wood to the stern and he watched it now and have gone again and it the promaga little circle. The blanket into this circle."
#
# "He say," the old man said. "Come on."
#
# "Qu How is fighting," the boy feel fish old man said. "Poor old man's hand and great DiMaggio would come inalan."
#
# He could take the sea. "Now I would not be a good fish."
#
# "I've a boat."
#
# "Good old man thought. But it is protered edge of the day."
#
# "Yes. I have to lash the great hands and the oars in?"
#
# "A my gray ballful at night and he said. For freight Haw dago.
#
# "I'll lash Say, grough the old man agreed, old man," the boy said. "You're very old man

# %%
# Start with [BOS] (Beginning Of Sequence) token, which is ID 2
bos_id = tokenizer.token_to_id("[BOS]")
context = torch.tensor([[bos_id]], dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=1000)[0].tolist()))
# Out:
#  out. We went to the start in the road and the river
# underhes road. There was a clear along I could see these hills
# village. There were along the river on a wide
# between our villa. I ruined all directer by
# off on the fall. It was pisms but the road that was cold,
# was a very small sunset boots, dropping on the road down and the
# road from the road flattened out of men on the hills that hills to
# except. Bonello was a face. He stood up and when the brush
# f everywhere, opening the bridge, too. The dust came down on
# in the carabinieri said
# the main road to a stone bridge of cafés. Bonello. The road was a arm was a
# each had been empty bottles. We went through I met Montoya to walk on the
# road, the
# prot, saw the south. I explained, then I saw the infield. In the rifles in the stone blond grew, a mile
# deep traffic chess-room. I did not know. I was too. I
# the post-morrow and damp ground white road. There
#
# other, modernind people.
#
# The Austrians had another quiet on the walls, before the dust in two lines in every windows had kept green sleeves
# until back, who had come and on his sisterting
# people. The boy becamehel were purked up and Bill was damn,” he lay back in the
# against the hedge. His
# sighted me and put it on down and put feeling around the black. There was
# the top of the rain and dusty.
#
# “For some wine-ghers,” he said. “I know what makes you have a boat? Is that start completely.”
#
# “All right to come here. It is enough to the bridge off suddenly.”
#
# “Good Christ we can sing,”
# Piani said. “Don’t
# them will be in your legs?” I asked.
#
# “Dos better.
#
# He was on it nearly over his clean in ’embin me in the orderly. He said there were sewread
# the step-eyed for Enrico, Lilvermouthors.
# The others could a mile except the
# evening, and asked him. He lay
# get bare post-book and tossed. It was a hot day. He asked to see the
# people and he loaded.
#
# “Ho hoves to sleep in the tle-morrow till . . . . . . .es with the fight.”
#
# I went off the sod and sat on the balcony. It was piled by the
# sitting in the bank and muddy boots, and George. She came over the stano and
# hospital, put my arm around her cheek-room.
#
# “Go on,” I said.
#
# “Hoally I. Manning,” Georgette put her head. Meyers. She looked out with me. His
# andoliders; the orderly wore at the sister
# around. It was up. Catherine shook my believed. I pulled down
# going to the barely at the elevator
# brush, by the collar. The white woman was out against it was gray the starlight. Across the
# black. A bottles was it out and furled beside me. There were many empty. The
# smoothly packed them went out and it around the hay bank. I could too
# would hit him. Then I went up to the stairs. We drove it
# through watched him to the table and rang the
# full of the sitrejucert and down on a trout mass glass, spout above the trees. Then I had
# waiter letter on a couple of my bags. Stone was much red and ahead of
# something and then came in to the old man and we went out and Bill and the tackle
# from the glasses. It was quite drunk went over and was dark in bed on and rode
# along a good. Behind were across the houses and the other in the
# together. He was a shower and the platform off a house
# him at the door. I drank a company I saw them and their eyes
# through.
#
# “Come in right, yes with the rooms,” Manera said.
#
# “The attack waved,” he said. “Unand some soup. I said. It’s over.”
#
# “Up. I knew I am very good and I will have crazy.”
#
# “How do you see our leave?”
#
# “Yes.”
#
# I don’t like everything and I put the papers.”
#
# “I washed back,” said I laughed. I saw her and pulled her to kiss her
# p bar with my letters
# mets on top.
#
# “I must have coffee to go down
